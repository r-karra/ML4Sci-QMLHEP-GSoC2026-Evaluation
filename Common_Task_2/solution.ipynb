# %% [markdown]
# # Common Task 2: Quark-Gluon Classification
#
# This notebook contains the solution for binary classification of quark and gluon jets.
#
# ## Overview
# - **Dataset**: Simulated jet physics data
# - **Task**: Binary classification (Quark vs Gluon)
# - **Framework**: JAX/Flax
# - **Target Metric**: AUC Score

# %%
import jax
import jax.numpy as jnp
from jax import random
import flax.linen as nn
import optax
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(42)
key = random.PRNGKey(42)

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
# TODO: Load your dataset here
# This section should include:
# 1. Data loading
# 2. Train/validation/test split
# 3. Normalization/preprocessing

print("Data loading placeholder - add your data loading code here")

# %% [markdown]
# ## Model Definition

# %%
class ResNetInspired(nn.Module):
    """ResNet-inspired model for quark/gluon classification."""
    
    @nn.compact
    def __call__(self, x):
        # TODO: Implement ResNet-inspired architecture
        x = nn.Dense(256)(x)
        x = nn.relu(x)
        residual = x
        x = nn.Dense(256)(x)
        x = nn.relu(x)
        x = x + residual
        x = nn.Dense(128)(x)
        x = nn.relu(x)
        x = nn.Dense(1)(x)
        return x

# %% [markdown]
# ## Training Loop

# %%
# TODO: Implement training loop
# Include:
# 1. Loss function definition
# 2. Optimization setup
# 3. Training and validation loops
# 4. Metrics tracking

print("Training placeholder - add your training code here")

# %% [markdown]
# ## Evaluation and Results

# %%
# TODO: Evaluate on test set
# Include:
# 1. Test set metrics (AUC, Accuracy)
# 2. ROC curve (save as roc_curve.png)
# 3. Confusion matrix
# 4. Results visualization

print("Evaluation placeholder - add your evaluation code here")
